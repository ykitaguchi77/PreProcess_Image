# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/PreProcess_Image_colab/blob/master/Divide_dataset_into_train_val_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**データセットをランダムに振り分け**
# train/val/test

# %%
"""
dataset-------1.jpg, 2.jpg. .....
↓

dataset---train--
        |
        |--val--
        |
        |--test--  


"""

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.utils.data as data
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import math
import shutil

#Advanced Pytorchから
import glob
import os.path as osp
import random
import json
from PIL import Image
from tqdm import tqdm
# %matplotlib inline

#サポートパッチのインポート
from google.colab.patches import cv2_imshow
import cv2

plt.ion()   # interactive mode
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Set random seem for reproducibility
manualSeed = 20200815
#manualSeed = random.randint(1, 10000) # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)
torch.cuda.manual_seed(manualSeed)

torch.torch.backends.cudnn.benchmark = True
torch.torch.backends.cudnn.enabled = True


'''
grav: 甲状腺眼症
cont: コントロール
黒の空白を挿入することにより225px*225pxの画像を生成、EfficientNetを用いて転移学習
－－－－－－－－－－－－－－
データの構造
gravcont.zip ------grav
               |---cont
'''                                     

#google driveをcolabolatoryにマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Random Seed:  20200815
# Mounted at /content/drive

# %% [markdown]
# #**シンプルに分割する場合**

# %%
"""
----dataset

↓

----dataset----train
            |--val
            |--

"""

# %% [markdown]
# #**set parameters**

# %%
orig_path = '/content/drive/MyDrive/Deep_learning/gravcont_all_500px'
dst_path = '/content/drive/MyDrive/Deep_learning/gravcont_all_500px_divided'

#trainとvalの割合を指定。残りがtestになる
rate_train = 0.74
rate_val = 0.185

# %% [markdown]
# #**process**

# %%
#振り分け枚数の確認
total = os.listdir(orig_path)
rate_train = rate_train
rate_val = rate_val
rate_test = 1-rate_train-rate_val

test = random.sample(total, int(len(total)*rate_test))
trainval = set(total)-set(test)
train = random.sample(trainval, int(len(trainval)*(rate_train/(rate_train+rate_val))))
val = set(trainval)-set(train)

print('total: '+str(len(total)))
print('train: '+str(len(train)))
print('val: '+str(len(val)))
print('test: '+str(len(test)))
# Out:
# total: 2
# train: 1
# val: 1
# test: 0

# %%
start = time.time()

if os.path.exists(dst_path):
    shutil.rmtree(dst_path)
os.makedirs(dst_path, exist_ok=True)


os.makedirs(dst_path +'/train', exist_ok=True)
os.makedirs(dst_path +'/val', exist_ok=True)
os.makedirs(dst_path +'/test', exist_ok=True)

l=0
for j in train:
    shutil.copy(orig_path+'/'+j, dst_path +'/train')
    print('train: '+str(l)+' images copied')
    l+=1

l=0
for j in val:
    shutil.copy(orig_path+'/'+j, dst_path +'/val')
    print('val: '+str(l)+' images copied')
    l+=1

l=0
for j in test:
    shutil.copy(orig_path+'/'+j, dst_path +'/test')
    print('test: '+str(l)+' images copied')
    l+=1


print('Process done!!')
elapsed_time = time.time() - start
print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")

# %% [markdown]
# #**親フォルダがある場合**

# %%
"""
dataset-----grav
         |
         |--cont

↓

dataset---train---grav
        |       |-cont
        |       
        |-val-----grav
        |       |-cont
        |
        |-test----grav
                |-cont

"""

# %%
orig_path = '/content/drive/MyDrive/Deep_learning/gravcont_all_500px'
dst_path = '/content/drive/MyDrive/Deep_learning/gravcont_all_500px_divided'

#trainとvalの割合を指定。残りがtestになる
rate_train = 0.74
rate_val = 0.185

# %%
#親フォルダ直下のディレクトリを探索
files = os.listdir(orig_path)
files_dir = [f for f in files if os.path.isdir(os.path.join(orig_path, f))]
print(files_dir)    # ['grav', 'cont']
# Out:
# ['grav', 'cont']

# %%
for i in files_dir:
    in_path = orig_path + "/" + i
    print(in_path)

    #振り分け枚数の確認
    total = os.listdir(in_path)
    rate_train = rate_train
    rate_val = rate_val
    rate_test = 1-rate_train-rate_val

    test = random.sample(total, int(len(total)*rate_test))
    trainval = set(total)-set(test)
    train = random.sample(trainval, int(len(trainval)*(rate_train/(rate_train+rate_val))))
    val = set(trainval)-set(train)

    print(i + ' total: '+str(len(total)))
    print(i + ' train: '+str(len(train)))
    print(i + ' val: '+str(len(val)))
    print(i + ' test: '+str(len(test)))
# Out:
# /content/drive/MyDrive/Deep_learning/gravcont_all_500px/grav
# grav total: 894
# grav train: 661
# grav val: 166
# grav test: 67
# /content/drive/MyDrive/Deep_learning/gravcont_all_500px/cont
# cont total: 1618
# cont train: 1197
# cont val: 300
# cont test: 121

# %%
start = time.time()

if os.path.exists(dst_path):
    shutil.rmtree(dst_path)
os.makedirs(dst_path, exist_ok=True)


for i in files_dir:

    os.makedirs(dst_path +'/train/' + i, exist_ok=True)
    os.makedirs(dst_path +'/val/' + i, exist_ok=True)
    os.makedirs(dst_path +'/test/' + i, exist_ok=True)

    #移動させる画像のパスを抜き出し
    in_path = orig_path + "/" + i
    print(in_path)

    total = os.listdir(in_path)
    rate_train = rate_train
    rate_val = rate_val
    rate_test = 1-rate_train-rate_val

    test = random.sample(total, int(len(total)*rate_test))
    trainval = set(total)-set(test)
    train = random.sample(trainval, int(len(trainval)*(rate_train/(rate_train+rate_val))))
    val = set(trainval)-set(train)

    #移動
    l=0
    for j in train:
        shutil.copy(orig_path+'/'+i+'/'+j, dst_path +'/train/' + i)
        print('train '+i+': '+str(l)+' images copied')
        l+=1

    l=0
    for j in val:
        shutil.copy(orig_path+'/'+i+'/'+j, dst_path +'/val/' + i)
        print('val: '+i+': '+str(l)+' images copied')
        l+=1

    l=0
    for j in test:
        shutil.copy(orig_path+'/'+i+'/'+j, dst_path +'/test/' + i)
        print('test: '+i+': '+str(l)+' images copied')
        l+=1


print('Process done!!')
elapsed_time = time.time() - start
print ("elapsed_time:{0}".format(elapsed_time) + "[sec]")
# Out:
# /content/drive/MyDrive/Deep_learning/gravcont_all_500px/grav
# train grav: 0 images copied
# train grav: 1 images copied
# train grav: 2 images copied
# train grav: 3 images copied
# train grav: 4 images copied
# train grav: 5 images copied
# train grav: 6 images copied
# train grav: 7 images copied
# train grav: 8 images copied
# train grav: 9 images copied
# train grav: 10 images copied
# train grav: 11 images copied
# train grav: 12 images copied
# train grav: 13 images copied
# train grav: 14 images copied
# train grav: 15 images copied
# train grav: 16 images copied
# train grav: 17 images copied
# train grav: 18 images copied
# train grav: 19 images copied
# train grav: 20 images copied
# train grav: 21 images copied
# train grav: 22 images copied
# train grav: 23 images copied
# train grav: 24 images copied
# train grav: 25 images copied
# train grav: 26 images copied
# train grav: 27 images copied
# train grav: 28 images copied
# train grav: 29 images copied
# train grav: 30 images copied
# train grav: 31 images copied
# train grav: 32 images copied
# train grav: 33 images copied
# train grav: 34 images copied
# train grav: 35 images copied
# train grav: 36 images copied
# train grav: 37 images copied
# train grav: 556 images copied
# train grav: 557 images copied
# train grav: 558 images copied
# train grav: 559 images copied
# train grav: 560 images copied
# train grav: 561 images copied
# train grav: 562 images copied
# train grav: 563 images copied
# train grav: 564 images copied
# train grav: 565 images copied
# train grav: 566 images copied
# train grav: 567 images copied
# train grav: 568 images copied
# train grav: 569 images copied
# train grav: 570 images copied
# train grav: 571 images copied
# train grav: 572 images copied
# train grav: 573 images copied
# train grav: 574 images copied
# train grav: 575 images copied
# train grav: 576 images copied
# train grav: 577 images copied
# train grav: 578 images copied
# train grav: 579 images copied
# train grav: 580 images copied
# train grav: 581 images copied
# train grav: 582 images copied
# train grav: 583 images copied
# train grav: 584 images copied
# train grav: 585 images copied
# train grav: 586 images copied
# train grav: 587 images copied
# train grav: 588 images copied
# train grav: 589 images copied
# train grav: 590 images copied
# train grav: 591 images copied
# train grav: 592 images copied
# train grav: 593 images copied
# train grav: 594 images copied
# train grav: 595 images copied
# train grav: 596 images copied
# train grav: 597 images copied
# train grav: 598 images copied
# train grav: 599 images copied
# train grav: 600 images copied
# train grav: 601 images copied
# train grav: 602 images copied
# train grav: 603 images copied
# train grav: 604 images copied
# train grav: 605 images copied
# train grav: 606 images copied
# train grav: 607 images copied
# train grav: 608 images copied
# train grav: 609 images copied
# train grav: 610 images copied
# train grav: 611 images copied
# train grav: 612 images copied
# train grav: 613 images copied
# train grav: 614 images copied
# train grav: 615 images copied
# train grav: 616 images copied
# train grav: 617 images copied
# train grav: 618 images copied
# train grav: 619 images copied
# train grav: 620 images copied
# train grav: 621 images copied
# train grav: 622 images copied
# train grav: 623 images copied
# train grav: 624 images copied
# train grav: 625 images copied
# train grav: 626 images copied
# train grav: 627 images copied
# train grav: 628 images copied
# train grav: 629 images copied
# train grav: 630 images copied
# train grav: 631 images copied
# train grav: 632 images copied
# train grav: 633 images copied
# train grav: 634 images copied
# train grav: 635 images copied
# train grav: 636 images copied
# train grav: 637 images copied
# train grav: 638 images copied
# train grav: 639 images copied
# train grav: 640 images copied
# train grav: 641 images copied
# train grav: 642 images copied
# train grav: 643 images copied
# train grav: 644 images copied
# train grav: 645 images copied
# train grav: 646 images copied
# train grav: 647 images copied
# train grav: 648 images copied
# train grav: 649 images copied
# train grav: 650 images copied
# train grav: 651 images copied
# train grav: 652 images copied
# train grav: 653 images copied
# train grav: 654 images copied
# train grav: 655 images copied
# train grav: 656 images copied
# train grav: 657 images copied
# train grav: 658 images copied
# train grav: 659 images copied
# train grav: 660 images copied
# val: grav: 0 images copied
# val: grav: 1 images copied
# val: grav: 2 images copied
# val: grav: 3 images copied
# val: grav: 4 images copied
# val: grav: 5 images copied
# val: grav: 6 images copied
# val: grav: 7 images copied
# val: grav: 8 images copied
# val: grav: 9 images copied
# val: grav: 10 images copied
# val: grav: 11 images copied
# val: grav: 12 images copied
# val: grav: 13 images copied
# val: grav: 14 images copied
# val: grav: 15 images copied
# val: grav: 16 images copied
# val: grav: 17 images copied
# val: grav: 18 images copied
# val: grav: 19 images copied
# val: grav: 20 images copied
# val: grav: 21 images copied
# val: grav: 22 images copied
# val: grav: 23 images copied
# val: grav: 24 images copied
# val: grav: 25 images copied
# val: grav: 26 images copied
# val: grav: 27 images copied
# val: grav: 28 images copied
# val: grav: 29 images copied
# val: grav: 30 images copied
# val: grav: 31 images copied
# val: grav: 32 images copied
# val: grav: 33 images copied
# val: grav: 34 images copied
# val: grav: 35 images copied
# val: grav: 36 images copied
# val: grav: 37 images copied
# val: grav: 38 images copied
# val: grav: 39 images copied
# val: grav: 40 images copied
# val: grav: 41 images copied
# val: grav: 42 images copied
# val: grav: 43 images copied
# val: grav: 44 images copied
# val: grav: 45 images copied
# val: grav: 46 images copied
# val: grav: 47 images copied
# val: grav: 48 images copied
# val: grav: 49 images copied
# val: grav: 50 images copied
# val: grav: 51 images copied
# val: grav: 52 images copied
# val: grav: 53 images copied
# val: grav: 54 images copied
# val: grav: 55 images copied
# val: grav: 56 images copied
# val: grav: 57 images copied
# val: grav: 58 images copied
# val: grav: 59 images copied
# val: grav: 60 images copied
# val: grav: 61 images copied
# val: grav: 62 images copied
# val: grav: 63 images copied
# val: grav: 64 images copied
# val: grav: 65 images copied
# val: grav: 66 images copied
# val: grav: 67 images copied
# val: grav: 68 images copied
# val: grav: 69 images copied
# val: grav: 70 images copied
# val: grav: 71 images copied
# val: grav: 72 images copied
# val: grav: 73 images copied
# val: grav: 74 images copied
# val: grav: 75 images copied
# val: grav: 76 images copied
# val: grav: 77 images copied
# val: grav: 78 images copied
# val: grav: 79 images copied
# val: grav: 80 images copied
# val: grav: 81 images copied
# val: grav: 82 images copied
# val: grav: 83 images copied
# val: grav: 84 images copied
# val: grav: 85 images copied
# val: grav: 86 images copied
# val: grav: 87 images copied
# val: grav: 88 images copied
# val: grav: 89 images copied
# val: grav: 90 images copied
# val: grav: 91 images copied
# val: grav: 92 images copied
# val: grav: 93 images copied
# val: grav: 94 images copied
# val: grav: 95 images copied
# val: grav: 96 images copied
# val: grav: 97 images copied
# val: grav: 98 images copied
# val: grav: 99 images copied
# val: grav: 100 images copied
# val: grav: 101 images copied
# val: grav: 102 images copied
# val: grav: 103 images copied
# val: grav: 104 images copied
# val: grav: 105 images copied
# val: grav: 106 images copied
# val: grav: 107 images copied
# val: grav: 108 images copied
# val: grav: 109 images copied
# val: grav: 110 images copied
# val: grav: 111 images copied
# val: grav: 112 images copied
# val: grav: 113 images copied
# val: grav: 114 images copied
# val: grav: 115 images copied
# val: grav: 116 images copied
# val: grav: 117 images copied
# val: grav: 118 images copied
# val: grav: 119 images copied
# val: grav: 120 images copied
# val: grav: 121 images copied
# val: grav: 122 images copied
# val: grav: 123 images copied
# val: grav: 124 images copied
# val: grav: 125 images copied
# val: grav: 126 images copied
# val: grav: 127 images copied
# val: grav: 128 images copied
# val: grav: 129 images copied
# val: grav: 130 images copied
# val: grav: 131 images copied
# val: grav: 132 images copied
# val: grav: 133 images copied
# val: grav: 134 images copied
# val: grav: 135 images copied
# val: grav: 136 images copied
# val: grav: 137 images copied
# val: grav: 138 images copied
# val: grav: 139 images copied
# val: grav: 140 images copied
# val: grav: 141 images copied
# val: grav: 142 images copied
# val: grav: 143 images copied
# val: grav: 144 images copied
# val: grav: 145 images copied
# val: grav: 146 images copied
# val: grav: 147 images copied
# val: grav: 148 images copied
# val: grav: 149 images copied
# val: grav: 150 images copied
# val: grav: 151 images copied
# val: grav: 152 images copied
# val: grav: 153 images copied
# val: grav: 154 images copied
# val: grav: 155 images copied
# val: grav: 156 images copied
# val: grav: 157 images copied
# val: grav: 158 images copied
# val: grav: 159 images copied
# val: grav: 160 images copied
# val: grav: 161 images copied
# val: grav: 162 images copied
# val: grav: 163 images copied
# val: grav: 164 images copied
# val: grav: 165 images copied
# test: grav: 0 images copied
# test: grav: 1 images copied
# test: grav: 2 images copied
# test: grav: 3 images copied
# test: grav: 4 images copied
# test: grav: 5 images copied
# test: grav: 6 images copied
# test: grav: 7 images copied
# test: grav: 8 images copied
# test: grav: 9 images copied
# test: grav: 10 images copied
# test: grav: 11 images copied
# test: grav: 12 images copied
# test: grav: 13 images copied
# test: grav: 14 images copied
# test: grav: 15 images copied
# test: grav: 16 images copied
# test: grav: 17 images copied
# test: grav: 18 images copied
# test: grav: 19 images copied
# test: grav: 20 images copied
# test: grav: 21 images copied
# test: grav: 22 images copied
# test: grav: 23 images copied
# test: grav: 24 images copied
# test: grav: 25 images copied
# test: grav: 26 images copied
# test: grav: 27 images copied
# test: grav: 28 images copied
# test: grav: 29 images copied
# test: grav: 30 images copied
# test: grav: 31 images copied
# test: grav: 32 images copied
# test: grav: 33 images copied
# test: grav: 34 images copied
# test: grav: 35 images copied
# test: grav: 36 images copied
# test: grav: 37 images copied
# test: grav: 38 images copied
# test: grav: 39 images copied
# test: grav: 40 images copied
# test: grav: 41 images copied
# test: grav: 42 images copied
# test: grav: 43 images copied
# test: grav: 44 images copied
# test: grav: 45 images copied
# test: grav: 46 images copied
# test: grav: 47 images copied
# test: grav: 48 images copied
# test: grav: 49 images copied
# test: grav: 50 images copied
# test: grav: 51 images copied
# test: grav: 52 images copied
# test: grav: 53 images copied
# test: grav: 54 images copied
# test: grav: 55 images copied
# test: grav: 56 images copied
# test: grav: 57 images copied
# test: grav: 58 images copied
# test: grav: 59 images copied
# test: grav: 60 images copied
# test: grav: 61 images copied
# test: grav: 62 images copied
# test: grav: 63 images copied
# test: grav: 64 images copied
# test: grav: 65 images copied
# test: grav: 66 images copied
# /content/drive/MyDrive/Deep_learning/gravcont_all_500px/cont
# train cont: 0 images copied
# train cont: 1 images copied
# train cont: 2 images copied
# train cont: 3 images copied
# train cont: 4 images copied
# train cont: 5 images copied
# train cont: 6 images copied
# train cont: 7 images copied
# train cont: 8 images copied
# train cont: 9 images copied
# train cont: 10 images copied
# train cont: 11 images copied
# train cont: 12 images copied
# train cont: 13 images copied
# train cont: 14 images copied
# train cont: 15 images copied
# train cont: 16 images copied
# train cont: 17 images copied
# train cont: 18 images copied
# train cont: 19 images copied
# train cont: 20 images copied
# train cont: 21 images copied
# train cont: 22 images copied
# train cont: 23 images copied
# train cont: 24 images copied
# train cont: 25 images copied
# train cont: 26 images copied
# train cont: 27 images copied
# train cont: 28 images copied
# train cont: 29 images copied
# train cont: 30 images copied
# train cont: 31 images copied
# train cont: 32 images copied
# train cont: 33 images copied
# train cont: 34 images copied
# train cont: 35 images copied
# train cont: 36 images copied
# train cont: 37 images copied
# train cont: 38 images copied
# train cont: 39 images copied
# train cont: 40 images copied
# train cont: 41 images copied
# train cont: 42 images copied
# train cont: 43 images copied
# train cont: 44 images copied
# train cont: 45 images copied
# train cont: 46 images copied
# train cont: 47 images copied
# train cont: 48 images copied
# train cont: 49 images copied
# train cont: 50 images copied
# train cont: 51 images copied
# train cont: 52 images copied
# train cont: 53 images copied
# train cont: 54 images copied
# train cont: 55 images copied
# train cont: 56 images copied
# train cont: 57 images copied
# train cont: 58 images copied
# train cont: 59 images copied
# train cont: 60 images copied
# train cont: 61 images copied
# train cont: 62 images copied
# train cont: 63 images copied
# train cont: 64 images copied
# train cont: 65 images copied
# train cont: 66 images copied
# train cont: 67 images copied
# train cont: 68 images copied
# train cont: 69 images copied
# train cont: 70 images copied
# train cont: 71 images copied
# train cont: 72 images copied
# train cont: 73 images copied
# train cont: 74 images copied
# train cont: 75 images copied
# train cont: 76 images copied
# train cont: 77 images copied
# train cont: 78 images copied
# train cont: 79 images copied
# train cont: 80 images copied
# train cont: 81 images copied
# train cont: 82 images copied
# train cont: 83 images copied
# train cont: 84 images copied
# train cont: 85 images copied
# train cont: 86 images copied
# train cont: 87 images copied
# train cont: 88 images copied
# train cont: 89 images copied
# train cont: 90 images copied
# train cont: 91 images copied
# train cont: 92 images copied
# train cont: 93 images copied
# train cont: 94 images copied
# train cont: 95 images copied
# train cont: 96 images copied
# train cont: 97 images copied
# train cont: 98 images copied
# train cont: 99 images copied
# train cont: 100 images copied
# train cont: 101 images copied
# train cont: 102 images copied
# train cont: 103 images copied
# train cont: 104 images copied
# train cont: 105 images copied
# train cont: 106 images copied
# train cont: 107 images copied
# train cont: 108 images copied
# train cont: 109 images copied
# train cont: 110 images copied
# train cont: 111 images copied
# train cont: 112 images copied
# train cont: 113 images copied
# train cont: 114 images copied
# train cont: 115 images copied
# train cont: 116 images copied
# train cont: 117 images copied
# train cont: 118 images copied
# train cont: 119 images copied
# train cont: 120 images copied
# train cont: 121 images copied
# train cont: 122 images copied
# train cont: 123 images copied
# train cont: 124 images copied
# train cont: 125 images copied
# train cont: 126 images copied
# train cont: 127 images copied
# train cont: 128 images copied
# train cont: 129 images copied
# train cont: 130 images copied
# train cont: 131 images copied
# train cont: 132 images copied
# train cont: 133 images copied
# train cont: 134 images copied
# train cont: 135 images copied
# train cont: 136 images copied
# train cont: 137 images copied
# train cont: 138 images copied
# train cont: 139 images copied
# train cont: 140 images copied
# train cont: 141 images copied
# train cont: 142 images copied
# train cont: 143 images copied
# train cont: 144 images copied
# train cont: 145 images copied
# train cont: 146 images copied
# train cont: 147 images copied
# train cont: 148 images copied
# train cont: 149 images copied
# train cont: 150 images copied
# train cont: 151 images copied
# train cont: 152 images copied
# train cont: 153 images copied
# train cont: 154 images copied
# train cont: 155 images copied
# train cont: 156 images copied
# train cont: 157 images copied
# train cont: 158 images copied
# train cont: 159 images copied
# train cont: 160 images copied
# train cont: 161 images copied
# train cont: 162 images copied
# train cont: 163 images copied
# train cont: 164 images copied
# train cont: 165 images copied
# train cont: 166 images copied
# train cont: 167 images copied
# train cont: 168 images copied
# train cont: 169 images copied
# train cont: 170 images copied
# train cont: 171 images copied
# train cont: 172 images copied
# train cont: 173 images copied
# train cont: 174 images copied
# train cont: 175 images copied
# train cont: 176 images copied
# train cont: 177 images copied
# train cont: 178 images copied
# train cont: 179 images copied
# train cont: 180 images copied
# train cont: 181 images copied
# train cont: 182 images copied
# train cont: 183 images copied
# train cont: 184 images copied
# train cont: 185 images copied
# train cont: 186 images copied
# train cont: 187 images copied
# train cont: 188 images copied
# train cont: 189 images copied
# train cont: 190 images copied
# train cont: 191 images copied
# train cont: 192 images copied
# train cont: 193 images copied
# train cont: 194 images copied
# train cont: 195 images copied
# train cont: 196 images copied
# train cont: 197 images copied
# train cont: 198 images copied
# train cont: 199 images copied
# train cont: 200 images copied
# train cont: 201 images copied
# train cont: 202 images copied
# train cont: 203 images copied
# train cont: 204 images copied
# train cont: 205 images copied
# train cont: 206 images copied
# train cont: 207 images copied
# train cont: 208 images copied
# train cont: 209 images copied
# train cont: 210 images copied
# train cont: 211 images copied
# train cont: 212 images copied
# train cont: 213 images copied
# train cont: 214 images copied
# train cont: 215 images copied
# train cont: 216 images copied
# train cont: 217 images copied
# train cont: 218 images copied
# train cont: 219 images copied
# train cont: 220 images copied
# train cont: 221 images copied
# train cont: 222 images copied
# train cont: 223 images copied
# train cont: 224 images copied
# train cont: 225 images copied
# train cont: 226 images copied
# train cont: 227 images copied
# train cont: 228 images copied
# train cont: 229 images copied
# train cont: 230 images copied
# train cont: 231 images copied
# train cont: 232 images copied
# train cont: 233 images copied
# train cont: 234 images copied
# train cont: 235 images copied
# train cont: 236 images copied
# train cont: 237 images copied
# train cont: 238 images copied
# train cont: 239 images copied
# train cont: 240 images copied
# train cont: 241 images copied
# train cont: 242 images copied
# train cont: 243 images copied
# train cont: 244 images copied
# train cont: 245 images copied
# train cont: 246 images copied
# train cont: 247 images copied
# train cont: 248 images copied
# train cont: 249 images copied
# train cont: 250 images copied
# train cont: 251 images copied
# train cont: 252 images copied
# train cont: 253 images copied
# train cont: 254 images copied
# train cont: 255 images copied
# train cont: 256 images copied
# train cont: 257 images copied
# train cont: 258 images copied
# train cont: 259 images copied
# train cont: 260 images copied
# train cont: 261 images copied
# train cont: 262 images copied
# train cont: 263 images copied
# train cont: 264 images copied
# train cont: 265 images copied
# train cont: 266 images copied
# train cont: 267 images copied
# train cont: 268 images copied
# train cont: 269 images copied
# train cont: 270 images copied
# train cont: 271 images copied
# train cont: 272 images copied
# train cont: 273 images copied
# train cont: 274 images copied
# train cont: 275 images copied
# train cont: 276 images copied
# train cont: 277 images copied
# train cont: 278 images copied
# train cont: 279 images copied
# train cont: 280 images copied
# train cont: 281 images copied
# train cont: 282 images copied
# train cont: 283 images copied
# train cont: 284 images copied
# train cont: 285 images copied
# train cont: 286 images copied
# train cont: 287 images copied
# train cont: 288 images copied
# train cont: 289 images copied
# train cont: 290 images copied
# train cont: 291 images copied
# train cont: 292 images copied
# train cont: 293 images copied
# train cont: 294 images copied
# train cont: 295 images copied
# train cont: 296 images copied
# train cont: 297 images copied
# train cont: 298 images copied
# train cont: 299 images copied
# train cont: 300 images copied
# train cont: 301 images copied
# train cont: 302 images copied
# train cont: 303 images copied
# train cont: 304 images copied
# train cont: 305 images copied
# train cont: 306 images copied
# train cont: 307 images copied
# train cont: 308 images copied
# train cont: 309 images copied
# train cont: 310 images copied
# train cont: 311 images copied
# train cont: 312 images copied
# train cont: 313 images copied
# train cont: 314 images copied
# train cont: 315 images copied
# train cont: 316 images copied
# train cont: 317 images copied
# train cont: 318 images copied
# train cont: 319 images copied
# train cont: 320 images copied
# train cont: 321 images copied
# train cont: 322 images copied
# train cont: 323 images copied
# train cont: 324 images copied
# train cont: 325 images copied
# train cont: 326 images copied
# train cont: 327 images copied
# train cont: 328 images copied
# train cont: 329 images copied
# train cont: 330 images copied
# train cont: 331 images copied
# train cont: 332 images copied
# train cont: 333 images copied
# train cont: 334 images copied
# train cont: 335 images copied
# train cont: 336 images copied
# train cont: 337 images copied
# train cont: 338 images copied
# train cont: 339 images copied
# train cont: 340 images copied
# train cont: 341 images copied
# train cont: 342 images copied
# train cont: 343 images copied
# train cont: 344 images copied
# train cont: 345 images copied
# train cont: 346 images copied
# train cont: 347 images copied
# train cont: 348 images copied
# train cont: 349 images copied
# train cont: 350 images copied
# train cont: 351 images copied
# train cont: 352 images copied
# train cont: 353 images copied
# train cont: 354 images copied
# train cont: 355 images copied
# train cont: 356 images copied
# train cont: 357 images copied
# train cont: 358 images copied
# train cont: 359 images copied
# train cont: 360 images copied
# train cont: 361 images copied
# train cont: 362 images copied
# train cont: 363 images copied
# train cont: 364 images copied
# train cont: 365 images copied
# train cont: 366 images copied
# train cont: 367 images copied
# train cont: 368 images copied
# train cont: 369 images copied
# train cont: 370 images copied
# train cont: 371 images copied
# train cont: 372 images copied
# train cont: 373 images copied
# train cont: 374 images copied
# train cont: 375 images copied
# train cont: 376 images copied
# train cont: 377 images copied
# train cont: 378 images copied
# train cont: 379 images copied
# train cont: 380 images copied
# train cont: 381 images copied
# train cont: 382 images copied
# train cont: 383 images copied
# train cont: 384 images copied
# train cont: 385 images copied
# train cont: 386 images copied
# train cont: 387 images copied
# train cont: 388 images copied
# train cont: 389 images copied
# train cont: 390 images copied
# train cont: 391 images copied
# train cont: 392 images copied
# train cont: 393 images copied
# train cont: 394 images copied
# train cont: 395 images copied
# train cont: 396 images copied
# train cont: 397 images copied
# train cont: 398 images copied
# train cont: 399 images copied
# train cont: 400 images copied
# train cont: 401 images copied
# train cont: 402 images copied
# train cont: 403 images copied
# train cont: 404 images copied
# train cont: 405 images copied
# train cont: 406 images copied
# train cont: 407 images copied
# train cont: 408 images copied
# train cont: 409 images copied
# train cont: 410 images copied
# train cont: 411 images copied
# train cont: 412 images copied
# train cont: 413 images copied
# train cont: 414 images copied
# train cont: 415 images copied
# train cont: 416 images copied
# train cont: 417 images copied
# train cont: 418 images copied
# train cont: 419 images copied
# train cont: 420 images copied
# train cont: 421 images copied
# train cont: 422 images copied
# train cont: 423 images copied
# train cont: 424 images copied
# train cont: 425 images copied
# train cont: 426 images copied
# train cont: 427 images copied
# train cont: 428 images copied
# train cont: 429 images copied
# train cont: 430 images copied
# train cont: 431 images copied
# train cont: 432 images copied
# train cont: 433 images copied
# train cont: 434 images copied
# train cont: 435 images copied
# train cont: 436 images copied
# train cont: 437 images copied
# train cont: 438 images copied
# train cont: 439 images copied
# train cont: 440 images copied
# train cont: 441 images copied
# train cont: 442 images copied
# train cont: 443 images copied
# train cont: 444 images copied
# train cont: 445 images copied
# train cont: 446 images copied
# train cont: 447 images copied
# train cont: 448 images copied
# train cont: 449 images copied
# train cont: 450 images copied
# train cont: 451 images copied
# train cont: 452 images copied
# train cont: 453 images copied
# train cont: 454 images copied
# train cont: 455 images copied
# train cont: 456 images copied
# train cont: 457 images copied
# train cont: 458 images copied
# train cont: 459 images copied
# train cont: 460 images copied
# train cont: 461 images copied
# train cont: 462 images copied
# train cont: 463 images copied
# train cont: 464 images copied
# train cont: 465 images copied
# train cont: 466 images copied
# train cont: 467 images copied
# train cont: 468 images copied
# train cont: 469 images copied
# train cont: 470 images copied
# train cont: 471 images copied
# train cont: 472 images copied
# train cont: 473 images copied
# train cont: 474 images copied
# train cont: 475 images copied
# train cont: 476 images copied
# train cont: 477 images copied
# train cont: 478 images copied
# train cont: 479 images copied
# train cont: 480 images copied
# train cont: 481 images copied
# train cont: 482 images copied
# train cont: 483 images copied
# train cont: 484 images copied
# train cont: 485 images copied
# train cont: 486 images copied
# train cont: 487 images copied
# train cont: 488 images copied
# train cont: 489 images copied
# train cont: 490 images copied
# train cont: 491 images copied
# train cont: 492 images copied
# train cont: 493 images copied
# train cont: 494 images copied
# train cont: 495 images copied
# train cont: 496 images copied
# train cont: 497 images copied
# train cont: 498 images copied
# train cont: 499 images copied
# train cont: 500 images copied
# train cont: 501 images copied
# train cont: 502 images copied
# train cont: 503 images copied
# train cont: 504 images copied
# train cont: 505 images copied
# train cont: 506 images copied
# train cont: 507 images copied
# train cont: 508 images copied
# train cont: 509 images copied
# train cont: 510 images copied
# train cont: 511 images copied
# train cont: 512 images copied
# train cont: 513 images copied
# train cont: 514 images copied
# train cont: 515 images copied
# train cont: 516 images copied
# train cont: 517 images copied
# train cont: 518 images copied
# train cont: 519 images copied
# train cont: 520 images copied
# train cont: 521 images copied
# train cont: 522 images copied
# train cont: 523 images copied
# train cont: 524 images copied
# train cont: 525 images copied
# train cont: 526 images copied
# train cont: 527 images copied
# train cont: 528 images copied
# train cont: 529 images copied
# train cont: 530 images copied
# train cont: 531 images copied
# train cont: 532 images copied
# train cont: 533 images copied
# train cont: 534 images copied
# train cont: 535 images copied
# train cont: 536 images copied
# train cont: 537 images copied
# train cont: 538 images copied
# train cont: 539 images copied
# train cont: 540 images copied
# train cont: 541 images copied
# train cont: 542 images copied
# train cont: 543 images copied
# train cont: 544 images copied
# train cont: 545 images copied
# train cont: 546 images copied
# train cont: 547 images copied
# train cont: 548 images copied
# train cont: 549 images copied
# train cont: 550 images copied
# train cont: 551 images copied
# train cont: 552 images copied
# train cont: 553 images copied
# train cont: 554 images copied
# train cont: 555 images copied
# train cont: 556 images copied
# train cont: 557 images copied
# train cont: 558 images copied
# train cont: 559 images copied
# train cont: 560 images copied
# train cont: 561 images copied
# train cont: 562 images copied
# train cont: 563 images copied
# train cont: 564 images copied
# train cont: 565 images copied
# train cont: 566 images copied
# train cont: 567 images copied
# train cont: 568 images copied
# train cont: 569 images copied
# train cont: 570 images copied
# train cont: 571 images copied
# train cont: 572 images copied
# train cont: 573 images copied
# train cont: 574 images copied
# train cont: 575 images copied
# train cont: 576 images copied
# train cont: 577 images copied
# train cont: 578 images copied
# train cont: 579 images copied
# train cont: 580 images copied
# train cont: 581 images copied
# train cont: 582 images copied
# train cont: 583 images copied
# train cont: 584 images copied
# train cont: 585 images copied
# train cont: 586 images copied
# train cont: 587 images copied
# train cont: 588 images copied
# train cont: 589 images copied
# train cont: 590 images copied
# train cont: 591 images copied
# train cont: 592 images copied
# train cont: 593 images copied
# train cont: 594 images copied
# train cont: 595 images copied
# train cont: 596 images copied
# train cont: 597 images copied
# train cont: 598 images copied
# train cont: 599 images copied
# train cont: 600 images copied
# train cont: 601 images copied
# train cont: 602 images copied
# train cont: 603 images copied
# train cont: 604 images copied
# train cont: 605 images copied
# train cont: 606 images copied
# train cont: 607 images copied
# train cont: 608 images copied
# train cont: 609 images copied
# train cont: 610 images copied
# train cont: 611 images copied
# train cont: 612 images copied
# train cont: 613 images copied
# train cont: 614 images copied
# train cont: 615 images copied
# train cont: 616 images copied
# train cont: 617 images copied
# train cont: 618 images copied
# train cont: 619 images copied
# train cont: 620 images copied
# train cont: 621 images copied
# train cont: 622 images copied
# train cont: 623 images copied
# train cont: 624 images copied
# train cont: 625 images copied
# train cont: 626 images copied
# train cont: 627 images copied
# train cont: 628 images copied
# train cont: 629 images copied
# train cont: 630 images copied
# train cont: 631 images copied
# train cont: 632 images copied
# train cont: 633 images copied
# train cont: 634 images copied
# train cont: 635 images copied
# train cont: 636 images copied
# train cont: 637 images copied
# train cont: 638 images copied
# train cont: 639 images copied
# train cont: 640 images copied
# train cont: 641 images copied
# train cont: 642 images copied
# train cont: 643 images copied
# train cont: 644 images copied
# train cont: 645 images copied
# train cont: 646 images copied
# train cont: 647 images copied
# train cont: 648 images copied
# train cont: 649 images copied
# train cont: 650 images copied
# train cont: 651 images copied
# train cont: 652 images copied
# train cont: 653 images copied
# train cont: 654 images copied
# train cont: 655 images copied
# train cont: 656 images copied
# train cont: 657 images copied
# train cont: 658 images copied
# train cont: 659 images copied
# train cont: 660 images copied
# train cont: 661 images copied
# train cont: 662 images copied
# train cont: 663 images copied
# train cont: 664 images copied
# train cont: 665 images copied
# train cont: 666 images copied
# train cont: 667 images copied
# train cont: 668 images copied
# train cont: 669 images copied
# train cont: 670 images copied
# train cont: 671 images copied
# train cont: 672 images copied
# train cont: 673 images copied
# train cont: 674 images copied
# train cont: 675 images copied
# train cont: 676 images copied
# train cont: 677 images copied
# train cont: 678 images copied
# train cont: 679 images copied
# train cont: 680 images copied
# train cont: 681 images copied
# train cont: 682 images copied
# train cont: 683 images copied
# train cont: 684 images copied
# train cont: 685 images copied
# train cont: 686 images copied
# train cont: 687 images copied
# train cont: 688 images copied
# train cont: 689 images copied
# train cont: 690 images copied
# train cont: 691 images copied
# train cont: 692 images copied
# train cont: 693 images copied
# train cont: 694 images copied
# train cont: 695 images copied
# train cont: 696 images copied
# train cont: 697 images copied
# train cont: 698 images copied
# train cont: 699 images copied
# train cont: 700 images copied
# train cont: 701 images copied
# train cont: 702 images copied
# train cont: 703 images copied
# train cont: 704 images copied
# train cont: 705 images copied
# train cont: 706 images copied
# train cont: 707 images copied
# train cont: 708 images copied
# train cont: 709 images copied
# train cont: 710 images copied
# train cont: 711 images copied
# train cont: 712 images copied
# train cont: 713 images copied
# train cont: 714 images copied
# train cont: 715 images copied
# train cont: 716 images copied
# train cont: 717 images copied
# train cont: 718 images copied
# train cont: 719 images copied
# train cont: 720 images copied
# ...
# train cont: 1074 images copied
# train cont: 1075 images copied
# train cont: 1076 images copied
# train cont: 1077 images copied
# train cont: 1078 images copied
# train cont: 1079 images copied
# train cont: 1080 images copied
# train cont: 1081 images copied
# train cont: 1082 images copied
# train cont: 1083 images copied
# train cont: 1084 images copied
# train cont: 1085 images copied
# train cont: 1086 images copied
# train cont: 1087 images copied
# train cont: 1088 images copied
# train cont: 1089 images copied
# train cont: 1090 images copied
# train cont: 1091 images copied
# train cont: 1092 images copied
# train cont: 1093 images copied
# train cont: 1094 images copied
# train cont: 1095 images copied
# train cont: 1096 images copied
# train cont: 1097 images copied
# train cont: 1098 images copied
# train cont: 1099 images copied
# train cont: 1100 images copied
# train cont: 1101 images copied
# train cont: 1102 images copied
# train cont: 1103 images copied
# train cont: 1104 images copied
# train cont: 1105 images copied
# train cont: 1106 images copied
# train cont: 1107 images copied
# train cont: 1108 images copied
# train cont: 1109 images copied
# train cont: 1110 images copied
# train cont: 1111 images copied
# train cont: 1112 images copied
# train cont: 1113 images copied
# train cont: 1114 images copied
# train cont: 1115 images copied
# train cont: 1116 images copied
# train cont: 1117 images copied
# train cont: 1118 images copied
# train cont: 1119 images copied
# train cont: 1120 images copied
# train cont: 1121 images copied
# train cont: 1122 images copied
# train cont: 1123 images copied
# train cont: 1124 images copied
# train cont: 1125 images copied
# train cont: 1126 images copied
# train cont: 1127 images copied
# train cont: 1128 images copied
# train cont: 1129 images copied
# train cont: 1130 images copied
# train cont: 1131 images copied
# train cont: 1132 images copied
# train cont: 1133 images copied
# train cont: 1134 images copied
# train cont: 1135 images copied
# train cont: 1136 images copied
# train cont: 1137 images copied
# train cont: 1138 images copied
# train cont: 1139 images copied
# train cont: 1140 images copied
# train cont: 1141 images copied
# train cont: 1142 images copied
# train cont: 1143 images copied
# train cont: 1144 images copied
# train cont: 1145 images copied
# train cont: 1146 images copied
# train cont: 1147 images copied
# train cont: 1148 images copied
# train cont: 1149 images copied
# train cont: 1150 images copied
# train cont: 1151 images copied
# train cont: 1152 images copied
# train cont: 1153 images copied
# train cont: 1154 images copied
# train cont: 1155 images copied
# train cont: 1156 images copied
# train cont: 1157 images copied
# train cont: 1158 images copied
# train cont: 1159 images copied
# train cont: 1160 images copied
# train cont: 1161 images copied
# train cont: 1162 images copied
# train cont: 1163 images copied
# train cont: 1164 images copied
# train cont: 1165 images copied
# train cont: 1166 images copied
# train cont: 1167 images copied
# train cont: 1168 images copied
# train cont: 1169 images copied
# train cont: 1170 images copied
# train cont: 1171 images copied
# train cont: 1172 images copied
# train cont: 1173 images copied
# train cont: 1174 images copied
# train cont: 1175 images copied
# train cont: 1176 images copied
# train cont: 1177 images copied
# train cont: 1178 images copied
# train cont: 1179 images copied
# train cont: 1180 images copied
# train cont: 1181 images copied
# train cont: 1182 images copied
# train cont: 1183 images copied
# train cont: 1184 images copied
# train cont: 1185 images copied
# train cont: 1186 images copied
# train cont: 1187 images copied
# train cont: 1188 images copied
# train cont: 1189 images copied
# train cont: 1190 images copied
# train cont: 1191 images copied
# train cont: 1192 images copied
# train cont: 1193 images copied
# train cont: 1194 images copied
# train cont: 1195 images copied
# train cont: 1196 images copied
# val: cont: 0 images copied
# val: cont: 1 images copied
# val: cont: 2 images copied
# val: cont: 3 images copied
# val: cont: 4 images copied
# val: cont: 5 images copied
# val: cont: 6 images copied
# val: cont: 7 images copied
# val: cont: 8 images copied
# val: cont: 9 images copied
# val: cont: 10 images copied
# val: cont: 11 images copied
# val: cont: 12 images copied
# val: cont: 13 images copied
# val: cont: 14 images copied
# val: cont: 15 images copied
# val: cont: 16 images copied
# val: cont: 17 images copied
# val: cont: 18 images copied
# val: cont: 19 images copied
# val: cont: 20 images copied
# val: cont: 21 images copied
# val: cont: 22 images copied
# val: cont: 23 images copied
# val: cont: 24 images copied
# val: cont: 25 images copied
# val: cont: 26 images copied
# val: cont: 27 images copied
# val: cont: 28 images copied
# val: cont: 29 images copied
# val: cont: 30 images copied
# val: cont: 31 images copied
# val: cont: 32 images copied
# val: cont: 33 images copied
# val: cont: 34 images copied
# val: cont: 35 images copied
# val: cont: 36 images copied
# val: cont: 37 images copied
# val: cont: 38 images copied
# val: cont: 39 images copied
# val: cont: 40 images copied
# val: cont: 41 images copied
# val: cont: 42 images copied
# val: cont: 43 images copied
# val: cont: 44 images copied
# val: cont: 45 images copied
# val: cont: 46 images copied
# val: cont: 47 images copied
# val: cont: 48 images copied
# val: cont: 49 images copied
# val: cont: 50 images copied
# val: cont: 51 images copied
# val: cont: 52 images copied
# val: cont: 53 images copied
# val: cont: 54 images copied
# val: cont: 55 images copied
# val: cont: 56 images copied
# val: cont: 57 images copied
# val: cont: 58 images copied
# val: cont: 59 images copied
# val: cont: 60 images copied
# val: cont: 61 images copied
# val: cont: 62 images copied
# val: cont: 63 images copied
# val: cont: 64 images copied
# val: cont: 65 images copied
# val: cont: 66 images copied
# val: cont: 67 images copied
# val: cont: 68 images copied
# val: cont: 69 images copied
# val: cont: 70 images copied
# val: cont: 71 images copied
# val: cont: 72 images copied
# val: cont: 73 images copied
# val: cont: 74 images copied
# val: cont: 75 images copied
# val: cont: 76 images copied
# val: cont: 77 images copied
# val: cont: 78 images copied
# val: cont: 79 images copied
# val: cont: 80 images copied
# val: cont: 81 images copied
# val: cont: 82 images copied
# val: cont: 83 images copied
# val: cont: 84 images copied
# val: cont: 85 images copied
# val: cont: 86 images copied
# val: cont: 87 images copied
# val: cont: 88 images copied
# val: cont: 89 images copied
# val: cont: 90 images copied
# val: cont: 91 images copied
# val: cont: 92 images copied
# val: cont: 93 images copied
# val: cont: 94 images copied
# val: cont: 95 images copied
# val: cont: 96 images copied
# val: cont: 97 images copied
# val: cont: 98 images copied
# val: cont: 99 images copied
# val: cont: 100 images copied
# val: cont: 101 images copied
# val: cont: 102 images copied
# val: cont: 103 images copied
# val: cont: 104 images copied
# val: cont: 105 images copied
# val: cont: 106 images copied
# val: cont: 107 images copied
# val: cont: 108 images copied
# val: cont: 109 images copied
# val: cont: 110 images copied
# val: cont: 111 images copied
# val: cont: 112 images copied
# val: cont: 113 images copied
# val: cont: 114 images copied
# val: cont: 115 images copied
# val: cont: 116 images copied
# val: cont: 117 images copied
# val: cont: 118 images copied
# val: cont: 119 images copied
# val: cont: 120 images copied
# val: cont: 121 images copied
# val: cont: 122 images copied
# val: cont: 123 images copied
# val: cont: 124 images copied
# val: cont: 125 images copied
# val: cont: 126 images copied
# val: cont: 127 images copied
# val: cont: 128 images copied
# val: cont: 129 images copied
# val: cont: 130 images copied
# val: cont: 131 images copied
# val: cont: 132 images copied
# val: cont: 133 images copied
# val: cont: 134 images copied
# val: cont: 135 images copied
# val: cont: 136 images copied
# val: cont: 137 images copied
# val: cont: 138 images copied
# val: cont: 139 images copied
# val: cont: 140 images copied
# val: cont: 141 images copied
# val: cont: 142 images copied
# val: cont: 143 images copied
# val: cont: 144 images copied
# val: cont: 145 images copied
# val: cont: 146 images copied
# val: cont: 147 images copied
# val: cont: 148 images copied
# val: cont: 149 images copied
# val: cont: 150 images copied
# val: cont: 151 images copied
# val: cont: 152 images copied
# val: cont: 153 images copied
# val: cont: 154 images copied
# val: cont: 155 images copied
# val: cont: 156 images copied
# val: cont: 157 images copied
# val: cont: 158 images copied
# val: cont: 159 images copied
# val: cont: 160 images copied
# val: cont: 161 images copied
# val: cont: 162 images copied
# val: cont: 163 images copied
# val: cont: 164 images copied
# val: cont: 165 images copied
# val: cont: 166 images copied
# val: cont: 167 images copied
# val: cont: 168 images copied
# val: cont: 169 images copied
# val: cont: 170 images copied
# val: cont: 171 images copied
# val: cont: 172 images copied
# val: cont: 173 images copied
# val: cont: 174 images copied
# val: cont: 175 images copied
# val: cont: 176 images copied
# val: cont: 177 images copied
# val: cont: 178 images copied
# val: cont: 179 images copied
# val: cont: 180 images copied
# val: cont: 181 images copied
# val: cont: 182 images copied
# val: cont: 183 images copied
# val: cont: 184 images copied
# val: cont: 185 images copied
# val: cont: 186 images copied
# val: cont: 187 images copied
# val: cont: 188 images copied
# val: cont: 189 images copied
# val: cont: 190 images copied
# val: cont: 191 images copied
# val: cont: 192 images copied
# val: cont: 193 images copied
# val: cont: 194 images copied
# val: cont: 195 images copied
# val: cont: 196 images copied
# val: cont: 197 images copied
# val: cont: 198 images copied
# val: cont: 199 images copied
# val: cont: 200 images copied
# val: cont: 201 images copied
# val: cont: 202 images copied
# val: cont: 203 images copied
# val: cont: 204 images copied
# val: cont: 205 images copied
# val: cont: 206 images copied
# val: cont: 207 images copied
# val: cont: 208 images copied
# val: cont: 209 images copied
# val: cont: 210 images copied
# val: cont: 211 images copied
# val: cont: 212 images copied
# val: cont: 213 images copied
# val: cont: 214 images copied
# val: cont: 215 images copied
# val: cont: 216 images copied
# val: cont: 217 images copied
# val: cont: 218 images copied
# val: cont: 219 images copied
# val: cont: 220 images copied
# val: cont: 221 images copied
# val: cont: 222 images copied
# val: cont: 223 images copied
# val: cont: 224 images copied
# val: cont: 225 images copied
# val: cont: 226 images copied
# val: cont: 227 images copied
# val: cont: 228 images copied
# val: cont: 229 images copied
# val: cont: 230 images copied
# val: cont: 231 images copied
# val: cont: 232 images copied
# val: cont: 233 images copied
# val: cont: 234 images copied
# val: cont: 235 images copied
# val: cont: 236 images copied
# val: cont: 237 images copied
# val: cont: 238 images copied
# val: cont: 239 images copied
# val: cont: 240 images copied
# val: cont: 241 images copied
# val: cont: 242 images copied
# val: cont: 243 images copied
# val: cont: 244 images copied
# val: cont: 245 images copied
# val: cont: 246 images copied
# val: cont: 247 images copied
# val: cont: 248 images copied
# val: cont: 249 images copied
# val: cont: 250 images copied
# val: cont: 251 images copied
# val: cont: 252 images copied
# val: cont: 253 images copied
# val: cont: 254 images copied
# val: cont: 255 images copied
# val: cont: 256 images copied
# val: cont: 257 images copied
# val: cont: 258 images copied
# val: cont: 259 images copied
# val: cont: 260 images copied
# val: cont: 261 images copied
# val: cont: 262 images copied
# val: cont: 263 images copied
# val: cont: 264 images copied
# val: cont: 265 images copied
# val: cont: 266 images copied
# val: cont: 267 images copied
# val: cont: 268 images copied
# val: cont: 269 images copied
# val: cont: 270 images copied
# val: cont: 271 images copied
# val: cont: 272 images copied
# val: cont: 273 images copied
# val: cont: 274 images copied
# val: cont: 275 images copied
# val: cont: 276 images copied
# val: cont: 277 images copied
# val: cont: 278 images copied
# val: cont: 279 images copied
# val: cont: 280 images copied
# val: cont: 281 images copied
# val: cont: 282 images copied
# val: cont: 283 images copied
# val: cont: 284 images copied
# val: cont: 285 images copied
# val: cont: 286 images copied
# val: cont: 287 images copied
# val: cont: 288 images copied
# val: cont: 289 images copied
# val: cont: 290 images copied
# val: cont: 291 images copied
# val: cont: 292 images copied
# val: cont: 293 images copied
# val: cont: 294 images copied
# val: cont: 295 images copied
# val: cont: 296 images copied
# val: cont: 297 images copied
# val: cont: 298 images copied
# val: cont: 299 images copied
# test: cont: 0 images copied
# test: cont: 1 images copied
# test: cont: 2 images copied
# test: cont: 3 images copied
# test: cont: 4 images copied
# test: cont: 5 images copied
# test: cont: 6 images copied
# test: cont: 7 images copied
# test: cont: 8 images copied
# test: cont: 9 images copied
# test: cont: 10 images copied
# test: cont: 11 images copied
# test: cont: 12 images copied
# test: cont: 13 images copied
# test: cont: 14 images copied
# test: cont: 15 images copied
# test: cont: 16 images copied
# test: cont: 17 images copied
# test: cont: 18 images copied
# test: cont: 19 images copied
# test: cont: 20 images copied
# test: cont: 21 images copied
# test: cont: 22 images copied
# test: cont: 23 images copied
# test: cont: 24 images copied
# test: cont: 25 images copied
# test: cont: 26 images copied
# test: cont: 27 images copied
# test: cont: 28 images copied
# test: cont: 29 images copied
# test: cont: 30 images copied
# test: cont: 31 images copied
# test: cont: 32 images copied
# test: cont: 33 images copied
# test: cont: 34 images copied
# test: cont: 35 images copied
# test: cont: 36 images copied
# test: cont: 37 images copied
# test: cont: 38 images copied
# test: cont: 39 images copied
# test: cont: 40 images copied
# test: cont: 41 images copied
# test: cont: 42 images copied
# test: cont: 43 images copied
# test: cont: 44 images copied
# test: cont: 45 images copied
# test: cont: 46 images copied
# test: cont: 47 images copied
# test: cont: 48 images copied
# test: cont: 49 images copied
# test: cont: 50 images copied
# test: cont: 51 images copied
# test: cont: 52 images copied
# test: cont: 53 images copied
# test: cont: 54 images copied
# test: cont: 55 images copied
# test: cont: 56 images copied
# test: cont: 57 images copied
# test: cont: 58 images copied
# test: cont: 59 images copied
# test: cont: 60 images copied
# test: cont: 61 images copied
# test: cont: 62 images copied
# test: cont: 63 images copied
# test: cont: 64 images copied
# test: cont: 65 images copied
# test: cont: 66 images copied
# test: cont: 67 images copied
# test: cont: 68 images copied
# test: cont: 69 images copied
# test: cont: 70 images copied
# test: cont: 71 images copied
# test: cont: 72 images copied
# test: cont: 73 images copied
# test: cont: 74 images copied
# test: cont: 75 images copied
# test: cont: 76 images copied
# test: cont: 77 images copied
# test: cont: 78 images copied
# test: cont: 79 images copied
# test: cont: 80 images copied
# test: cont: 81 images copied
# test: cont: 82 images copied
# test: cont: 83 images copied
# test: cont: 84 images copied
# test: cont: 85 images copied
# test: cont: 86 images copied
# test: cont: 87 images copied
# test: cont: 88 images copied
# test: cont: 89 images copied
# test: cont: 90 images copied
# test: cont: 91 images copied
# test: cont: 92 images copied
# test: cont: 93 images copied
# test: cont: 94 images copied
# test: cont: 95 images copied
# test: cont: 96 images copied
# test: cont: 97 images copied
# test: cont: 98 images copied
# test: cont: 99 images copied
# test: cont: 100 images copied
# test: cont: 101 images copied
# test: cont: 102 images copied
# test: cont: 103 images copied
# test: cont: 104 images copied
# test: cont: 105 images copied
# test: cont: 106 images copied
# test: cont: 107 images copied
# test: cont: 108 images copied
# test: cont: 109 images copied
# test: cont: 110 images copied
# test: cont: 111 images copied
# test: cont: 112 images copied
# test: cont: 113 images copied
# test: cont: 114 images copied
# test: cont: 115 images copied
# test: cont: 116 images copied
# test: cont: 117 images copied
# test: cont: 118 images copied
# test: cont: 119 images copied
# test: cont: 120 images copied
# Process done!!
# elapsed_time:29.998658180236816[sec]

# %% [markdown]
# #**フォルダとその中身を削除するスクリプト**

# %%
#フォルダを削除するスクリプト
directory = '/content/drive/MyDrive/Deep_learning/Olympia_dataset/dataset_500px_divided'
files = os.listdir(directory)
print(directory)
print(files)

for i in files:
    try:
        os.remove(directory+'/'+i)
    except IsADirectoryError:
        pass

shutil.rmtree(directory)
